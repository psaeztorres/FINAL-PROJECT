# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns',None)

# %%
spain = pd.read_csv('data/spain_global.csv')

# %%
spain.head()
# Out:
#                  project class country unit     status  capacity  start_year  \
# 0    Aboño power station  coal   Spain  MWh  operating  259200.0      1974.0
# 1    Aboño power station  coal   Spain  MWh  operating  400464.0      1985.0
# 2  Alcúdia power station  coal   Spain  MWh    retired   90000.0      1981.0
# 3  Alcúdia power station  coal   Spain  MWh    retired   90000.0      1982.0
# 4  Alcúdia power station  coal   Spain  MWh  operating   93600.0      1997.0
#
#          owner       lat      lng  \
# 0   HC Energia  43.55356 -5.72185
# 1   HC Energia  43.55356 -5.72185
# 2  GESA-Endesa  39.81075  3.09141
# 3  GESA-Endesa  39.81075  3.09141
# 4  GESA-Endesa  39.81075  3.09141
#
#                                              url      aacc
# 0  https://www.gem.wiki/Abo%C3%B1o_power_station  Asturias
# 1  https://www.gem.wiki/Abo%C3%B1o_power_station  Asturias
# 2     https://www.gem.wiki/Alcúdia_power_station  Baleares
# ...

# %%
spain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2987 entries, 0 to 2986
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   project     2987 non-null   object
#  1   class       2987 non-null   object
#  2   country     2987 non-null   object
#  3   unit        2987 non-null   object
#  4   status      2987 non-null   object
#  5   capacity    2987 non-null   float64
#  6   start_year  1526 non-null   float64
#  7   owner       2385 non-null   object
#  8   lat         2987 non-null   float64
#  9   lng         2987 non-null   float64
#  10  url         2987 non-null   object
#  11  aacc        2919 non-null   object
# dtypes: float64(4), object(8)
# memory usage: 280.2+ KB

# %%
gen = pd.read_csv('data/gen.csv')

# %%
gen.shape
# Out:
# (1692, 8)

# %%
result = gen[(gen['aacc'] == 'Madrid') & (gen['class'] == 'solar')]
result.shape
# Out:
# (10, 8)

# %%
dem = pd.read_csv("data/demand.csv")

# %%
dem.sample()
# Out:
#     Unnamed: 0    class  type        date       value  percentage      aacc  \
# 77          77  Demanda   NaN  2018-01-01  436553.899           1  Baleares
#
#    unit
# 77  MWh

# %%
dem['aacc'].unique()
# Out:
# array(['Canarias', 'Baleares', 'Ceuta', 'Melilla', 'Andalucia', 'Aragon',
#        'Cantabria', 'Castilla-La Mancha', 'Castilla-Leon', 'Cataluña',
#        'Pais Vasco', 'Asturias', 'Madrid', 'Navarra', 'Valencia',
#        'Extremadura', 'Galicia', 'La Rioja', 'Murcia'], dtype=object)

# %%
prueba.head(10)
# Out:
#      Unnamed: 0    class  type        date        value  percentage      aacc  \
# 9             9  Demanda   NaN  2014-01-01  4100446.945           1  Cataluña
# 28           28  Demanda   NaN  2015-01-01  4166773.739           1  Cataluña
# 47           47  Demanda   NaN  2016-01-01  3979236.621           1  Cataluña
# 66           66  Demanda   NaN  2017-01-01  4327712.209           1  Cataluña
# 85           85  Demanda   NaN  2018-01-01  4140577.062           1  Cataluña
# 104         104  Demanda   NaN  2019-01-01  4346165.016           1  Cataluña
# 123         123  Demanda   NaN  2020-01-01  4180533.867           1  Cataluña
# 142         142  Demanda   NaN  2021-01-01  4205890.778           1  Cataluña
# 161         161  Demanda   NaN  2022-01-01  3978813.799           1  Cataluña
# 180         180  Demanda   NaN  2023-01-01  3444370.992           1  Cataluña
#
#     unit
# 9    MWh
# 28   MWh
# 47   MWh
# 66   MWh
# 85   MWh
# 104  MWh
# 123  MWh
# 142  MWh
# 161  MWh
# ...

# %%
spain[spain['aacc']== 'Castilla-Leon']
# Out:
#                                         project       class country unit  \
# 6                        Anllares power station        coal   Spain  MWh
# 15                    Compostilla power station        coal   Spain  MWh
# 16                    Compostilla power station        coal   Spain  MWh
# 17                    Compostilla power station        coal   Spain  MWh
# 18                    Compostilla power station        coal   Spain  MWh
# ...                                         ...         ...     ...  ...
# 2950             Villacampo hydroelectric plant  hydropower   Spain  MWh
# 2951              Villarino hydroelectric plant  hydropower   Spain  MWh
# 2952             Cubillos del Sil power station   bioenergy   Spain  MWh
# 2979  Santa Maria De Garona nuclear power plant     nuclear   Spain  MWh
# 2980                 Sayago nuclear power plant     nuclear   Spain  MWh
#
#          status  capacity  start_year  \
# 6       retired  262800.0      1982.0
# ...
